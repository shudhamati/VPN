# %%
import numpy as np 
import pandas as pd 
from scipy.io import arff
import matplotlib.pyplot as plt
import seaborn as sns 
pd.pandas.set_option('display.max_columns',None)

# %%
data=arff.loadarff("C:\\Users\\Shuddhamati\\Desktop\\datasets\\Scenario A1\\Scenario A1\\TimeBasedFeatures-Dataset-30s-VPN.arff")

# %%
train=pd.DataFrame(data[0])

# %%
train
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14646       332.0        -1.0        -1.0        -1.0        -1.0
# 14647       297.0        -1.0        -1.0        -1.0        -1.0
# 14648    251872.0        -1.0        -1.0        -1.0        -1.0
# 14649       304.0        -1.0        -1.0        -1.0        -1.0
# 14650       245.0        -1.0        -1.0        -1.0        -1.0
#
#             max_fiat       max_biat     mean_fiat     mean_biat  \
# 0      314115.301370  360993.158730  1.306745e+06  1.389355e+06
# ...

# %%
train.to_csv('new.csv')

# %%
df=pd.read_csv("C:\\Users\\Shuddhamati\\Desktop\\datasets\\Scenario A1\\Scenario A1\\new.csv")

# %%
df
# Out:
#        Unnamed: 0    duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0               0  22930417.0        18.0         4.0  10995965.0  10960941.0
# 1               1  25199304.0        16.0         4.0  11037969.0  10851858.0
# 2               2  29772995.0        17.0         7.0   4093396.0   3956161.0
# 3               3  29609149.0        22.0         6.0   3954677.0   3943698.0
# 4               4   7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...         ...
# 14646       14646       332.0        -1.0        -1.0        -1.0        -1.0
# 14647       14647       297.0        -1.0        -1.0        -1.0        -1.0
# 14648       14648    251872.0        -1.0        -1.0        -1.0        -1.0
# 14649       14649       304.0        -1.0        -1.0        -1.0        -1.0
# 14650       14650       245.0        -1.0        -1.0        -1.0        -1.0
#
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14646       332.0        -1.0        -1.0        -1.0        -1.0
# 14647       297.0        -1.0        -1.0        -1.0        -1.0
# 14648    251872.0        -1.0        -1.0        -1.0        -1.0
# 14649       304.0        -1.0        -1.0        -1.0        -1.0
# 14650       245.0        -1.0        -1.0        -1.0        -1.0
#
#             max_fiat       max_biat     mean_fiat     mean_biat  \
# 0      314115.301370  360993.158730  1.306745e+06  1.389355e+06
# ...

# %%
df.drop(df[(df['total_fiat'])==-1].index,inplace=True)
df.drop(df[(df['total_biat'])==-1].index,inplace=True)

# %%
print(df.shape)
# Out:
# (11312, 24)

# %%
df
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
df['min_active']=df.replace(-1,df['min_active'].mean())

# %%
df['mean_active']=df.replace(0,df['mean_active'].mean())

# %%
df['max_active']=df.replace(-1,df['max_active'].mean())
df['std_active']=df.replace(0,df['std_active'].mean())
df['min_idle']=df.replace(-1,df['min_idle'].mean())
df['max_idle']=df.replace(-1,df['max_idle'].mean())
df['std_idle']=df.replace(0,df['std_idle'].mean())
df['mean_idle']=df.replace(0,df['mean_idle'].mean())

# %%
df
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
df.to_csv("dataClean.csv")

# %%
df1=pd.read_csv('C:\\Users\\Shuddhamati\\dataClean.csv')

# %%
df1.drop('Unnamed: 0',axis=1)
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 11307  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 11308  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 11309    200856.0       146.0        46.0    100200.0    100679.0
# 11310    202996.0       152.0        39.0    101684.0    101305.0
# 11311    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
dummies=pd.get_dummies(df.class1)

# %%
dummies
# Out:
#        b'Non-VPN'  b'VPN'
# 0               1       0
# 1               1       0
# 2               1       0
# 3               1       0
# 4               1       0
# ...           ...     ...
# 14605           1       0
# 14608           1       0
# 14621           1       0
# 14622           1       0
# 14623           1       0
#
# [11312 rows x 2 columns]

# %%
merged=pd.concat([df,dummies],axis='columns')
merged
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
df_vpn.head(10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-2eb820ae60d2> in <module>
# ----> 1 df_vpn.head(10)
#
# NameError: name 'df_vpn' is not defined

# %%
df_nonvpn.head()

# %%
plt.scatter(df_vpn['std_idle'],df_vpn['std_active'],marker='+',color='green')
plt.scatter(df_nonvpn['std_idle'],df_nonvpn['std_active'],marker='+',color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
df.columns

# %%
column_name=header.tolist()
column_name

# %%
var=merged.class1

# %%
var

# %%
var2=merged.drop('class1',axis=1)

# %%
var2
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-d5242c061de5> in <module>
# ----> 1 knn.fit()
#
# TypeError: fit() missing 2 required positional arguments: 'X' and 'y'

# %%
var
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-84ddba356ca3> in <module>
# ----> 1 var
#
# NameError: name 'var' is not defined

# %%
var2.columns = var2.columns.str.replace("'"," ")

# %%
var2
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
var2.columns = var2.columns.str.replace("b VPN","VPN")

# %%
var2
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
var2.columns = var2.columns.str.replace("b Non-VPN","NONVPN")

# %%
var2
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
non_vpn=var2.columns[[23]]
var2.drop(var2.columns[[23]], axis=1, inplace=True)

# %%
var2.drop(var2.columns[[22]], axis=1, inplace=True)

# %%
var2
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
target=merged.iloc[:,24:26]
merged
# Out:
#          duration  total_fiat  total_biat    min_fiat    min_biat  \
# 0      22930417.0        18.0         4.0  10995965.0  10960941.0
# 1      25199304.0        16.0         4.0  11037969.0  10851858.0
# 2      29772995.0        17.0         7.0   4093396.0   3956161.0
# 3      29609149.0        22.0         6.0   3954677.0   3943698.0
# 4       7863522.0        30.0         8.0   2067690.0   2068091.0
# ...           ...         ...         ...         ...         ...
# 14605  14253939.0   7002496.0   6995059.0   7006795.0   7042458.0
# 14608  14207249.0   6998355.0   6991367.0   7015795.0   6997997.0
# 14621    200856.0       146.0        46.0    100200.0    100679.0
# 14622    202996.0       152.0        39.0    101684.0    101305.0
# 14623    201622.0       163.0        43.0    100448.0    101182.0
#
#            max_fiat      max_biat     mean_fiat     mean_biat  \
# 0      3.141153e+05  3.609932e+05  1.306745e+06  1.389355e+06
# ...

# %%
target
# Out:
#        b'Non-VPN'  b'VPN'
# 0               1       0
# 1               1       0
# 2               1       0
# 3               1       0
# 4               1       0
# ...           ...     ...
# 14605           1       0
# 14608           1       0
# 14621           1       0
# 14622           1       0
# 14623           1       0
#
# [11312 rows x 2 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3)

# %%
knn.fit(var2,target)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
knn.score(var2.iloc[1:1000],target.iloc[1:1000])
# Out:
# 0.8238238238238238
